# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %%
def get_weather_json(city, api_key):
    
    url = "http://api.openweathermap.org/data/2.5/weather?units=imperial"
    r = requests.get(url, params={
        "appid": api_key,
        "q": city})
    if r.status_code == 200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
count = 0
out_cities = []

for city in cities:
    out_city = get_weather_json(city, api_key)
    if out_city:
        out_cities.append(out_city)
        count += 1
        print("Processing Record " + str(count) + " for ")
    else:
        print("City not found. Skipping City...")
# Out:
# Processing Record 1 for
# Processing Record 2 for
# City not found. Skipping City...
# Processing Record 3 for
# Processing Record 4 for
# Processing Record 5 for
# Processing Record 6 for
# City not found. Skipping City...
# City not found. Skipping City...
# Processing Record 7 for
# City not found. Skipping City...
# Processing Record 8 for
# City not found. Skipping City...
# Processing Record 9 for
# Processing Record 10 for
# Processing Record 11 for
# Processing Record 12 for
# Processing Record 13 for
# Processing Record 14 for
# Processing Record 15 for
# Processing Record 16 for
# Processing Record 17 for
# Processing Record 18 for
# Processing Record 19 for
# Processing Record 20 for
# Processing Record 21 for
# Processing Record 22 for
# Processing Record 23 for
# Processing Record 24 for
# Processing Record 25 for
# Processing Record 26 for
# Processing Record 27 for
# Processing Record 28 for
# Processing Record 29 for
# Processing Record 30 for
# Processing Record 31 for
# Processing Record 32 for
# Processing Record 33 for
# Processing Record 34 for
# Processing Record 35 for
# Processing Record 36 for
# Processing Record 37 for
# Processing Record 38 for
# Processing Record 39 for
# Processing Record 40 for
# Processing Record 41 for
# Processing Record 42 for
# Processing Record 43 for
# Processing Record 44 for
# Processing Record 45 for
# Processing Record 46 for
# Processing Record 47 for
# Processing Record 48 for
# Processing Record 49 for
# Processing Record 50 for
# Processing Record 51 for
# Processing Record 52 for
# Processing Record 53 for
# Processing Record 54 for
# Processing Record 55 for
# Processing Record 56 for
# Processing Record 57 for
# Processing Record 58 for
# Processing Record 59 for
# Processing Record 60 for
# Processing Record 61 for
# Processing Record 62 for
# Processing Record 63 for
# Processing Record 64 for
# Processing Record 65 for
# City not found. Skipping City...
# Processing Record 66 for
# Processing Record 67 for
# Processing Record 68 for
# Processing Record 69 for
# Processing Record 70 for
# Processing Record 71 for
# Processing Record 72 for
# Processing Record 73 for
# Processing Record 74 for
# City not found. Skipping City...
# Processing Record 75 for
# Processing Record 76 for
# Processing Record 77 for
# Processing Record 78 for
# Processing Record 79 for
# Processing Record 80 for
# Processing Record 81 for
# Processing Record 82 for
# Processing Record 83 for
# Processing Record 84 for
# Processing Record 85 for
# Processing Record 86 for
# Processing Record 87 for
# Processing Record 88 for
# City not found. Skipping City...
# Processing Record 89 for
# Processing Record 90 for
# Processing Record 91 for
# Processing Record 92 for
# Processing Record 93 for
# Processing Record 94 for
# Processing Record 95 for
# Processing Record 96 for
# Processing Record 97 for
# Processing Record 98 for
# Processing Record 99 for
# Processing Record 100 for
# Processing Record 101 for
# Processing Record 102 for
# Processing Record 103 for
# Processing Record 104 for
# Processing Record 105 for
# Processing Record 106 for
# Processing Record 107 for
# Processing Record 108 for
# Processing Record 109 for
# Processing Record 110 for
# Processing Record 111 for
# Processing Record 112 for
# Processing Record 113 for
# Processing Record 114 for
# City not found. Skipping City...
# City not found. Skipping City...
# Processing Record 115 for
# Processing Record 116 for
# Processing Record 117 for
# Processing Record 118 for
# Processing Record 119 for
# Processing Record 120 for
# Processing Record 121 for
# Processing Record 122 for
# Processing Record 123 for
# Processing Record 124 for
# Processing Record 125 for
# Processing Record 126 for
# Processing Record 127 for
# Processing Record 128 for
# Processing Record 129 for
# Processing Record 130 for
# Processing Record 131 for
# Processing Record 132 for
# Processing Record 133 for
# Processing Record 134 for
# City not found. Skipping City...
# Processing Record 135 for
# Processing Record 136 for
# Processing Record 137 for
# Processing Record 138 for
# City not found. Skipping City...
# Processing Record 139 for
# Processing Record 140 for
# Processing Record 141 for
# Processing Record 142 for
# Processing Record 143 for
# Processing Record 144 for
# City not found. Skipping City...
# Processing Record 145 for
# Processing Record 146 for
# Processing Record 147 for
# Processing Record 148 for
# Processing Record 149 for
# Processing Record 150 for
# Processing Record 151 for
# Processing Record 152 for
# Processing Record 153 for
# Processing Record 154 for
# Processing Record 155 for
# Processing Record 156 for
# Processing Record 157 for
# Processing Record 158 for
# Processing Record 159 for
# City not found. Skipping City...
# Processing Record 160 for
# Processing Record 161 for
# City not found. Skipping City...
# Processing Record 162 for
# City not found. Skipping City...
# Processing Record 163 for
# Processing Record 164 for
# Processing Record 165 for
# Processing Record 166 for
# City not found. Skipping City...
# Processing Record 167 for
# Processing Record 168 for
# Processing Record 169 for
# Processing Record 170 for
# Processing Record 171 for
# City not found. Skipping City...
# City not found. Skipping City...
# Processing Record 172 for
# Processing Record 173 for
# Processing Record 174 for
# Processing Record 175 for
# Processing Record 176 for
# City not found. Skipping City...
# Processing Record 177 for
# Processing Record 178 for
# Processing Record 179 for
# Processing Record 180 for
# Processing Record 181 for
# City not found. Skipping City...
# Processing Record 182 for
# Processing Record 183 for
# Processing Record 184 for
# Processing Record 185 for
# Processing Record 186 for
# Processing Record 187 for
# Processing Record 188 for
# Processing Record 189 for
# Processing Record 190 for
# City not found. Skipping City...
# Processing Record 191 for
# Processing Record 192 for
# Processing Record 193 for
# Processing Record 194 for
# Processing Record 195 for
# Processing Record 196 for
# Processing Record 197 for
# Processing Record 198 for
# Processing Record 199 for
# Processing Record 200 for
# Processing Record 201 for
# Processing Record 202 for
# Processing Record 203 for
# Processing Record 204 for
# City not found. Skipping City...
# Processing Record 205 for
# Processing Record 206 for
# Processing Record 207 for
# Processing Record 208 for
# Processing Record 209 for
# Processing Record 210 for
# Processing Record 211 for
# Processing Record 212 for
# City not found. Skipping City...
# Processing Record 213 for
# Processing Record 214 for
# Processing Record 215 for
# Processing Record 216 for
# Processing Record 217 for
# Processing Record 218 for
# Processing Record 219 for
# Processing Record 220 for
# Processing Record 221 for
# Processing Record 222 for
# Processing Record 223 for
# Processing Record 224 for
# Processing Record 225 for
# Processing Record 226 for
# Processing Record 227 for
# Processing Record 228 for
# Processing Record 229 for
# Processing Record 230 for
# City not found. Skipping City...
# Processing Record 231 for
# Processing Record 232 for
# City not found. Skipping City...
# Processing Record 233 for
# Processing Record 234 for
# Processing Record 235 for
# Processing Record 236 for
# Processing Record 237 for
# Processing Record 238 for
# Processing Record 239 for
# Processing Record 240 for
# Processing Record 241 for
# Processing Record 242 for
# Processing Record 243 for
# Processing Record 244 for
# Processing Record 245 for
# Processing Record 246 for
# Processing Record 247 for
# Processing Record 248 for
# Processing Record 249 for
# Processing Record 250 for
# Processing Record 251 for
# City not found. Skipping City...
# Processing Record 252 for
# Processing Record 253 for
# Processing Record 254 for
# City not found. Skipping City...
# Processing Record 255 for
# Processing Record 256 for
# Processing Record 257 for
# Processing Record 258 for
# Processing Record 259 for
# Processing Record 260 for
# Processing Record 261 for
# City not found. Skipping City...
# Processing Record 262 for
# Processing Record 263 for
# Processing Record 264 for
# Processing Record 265 for
# Processing Record 266 for
# Processing Record 267 for
# Processing Record 268 for
# Processing Record 269 for
# Processing Record 270 for
# Processing Record 271 for
# Processing Record 272 for
# Processing Record 273 for
# City not found. Skipping City...
# Processing Record 274 for
# Processing Record 275 for
# Processing Record 276 for
# Processing Record 277 for
# Processing Record 278 for
# Processing Record 279 for
# Processing Record 280 for
# Processing Record 281 for
# City not found. Skipping City...
# Processing Record 282 for
# Processing Record 283 for
# Processing Record 284 for
# Processing Record 285 for
# Processing Record 286 for
# City not found. Skipping City...
# Processing Record 287 for
# Processing Record 288 for
# Processing Record 289 for
# Processing Record 290 for
# Processing Record 291 for
# Processing Record 292 for
# Processing Record 293 for
# Processing Record 294 for
# Processing Record 295 for
# Processing Record 296 for
# Processing Record 297 for
# Processing Record 298 for
# Processing Record 299 for
# Processing Record 300 for
# Processing Record 301 for
# Processing Record 302 for
# Processing Record 303 for
# Processing Record 304 for
# Processing Record 305 for
# Processing Record 306 for
# Processing Record 307 for
# Processing Record 308 for
# Processing Record 309 for
# City not found. Skipping City...
# City not found. Skipping City...
# Processing Record 310 for
# Processing Record 311 for
# Processing Record 312 for
# Processing Record 313 for
# Processing Record 314 for
# Processing Record 315 for
# Processing Record 316 for
# Processing Record 317 for
# Processing Record 318 for
# Processing Record 319 for
# Processing Record 320 for
# Processing Record 321 for
# City not found. Skipping City...
# Processing Record 322 for
# Processing Record 323 for
# Processing Record 324 for
# Processing Record 325 for
# Processing Record 326 for
# Processing Record 327 for
# Processing Record 328 for
# Processing Record 329 for
# Processing Record 330 for
# Processing Record 331 for
# Processing Record 332 for
# Processing Record 333 for
# Processing Record 334 for
# Processing Record 335 for
# Processing Record 336 for
# Processing Record 337 for
# City not found. Skipping City...
# Processing Record 338 for
# Processing Record 339 for
# Processing Record 340 for
# Processing Record 341 for
# Processing Record 342 for
# Processing Record 343 for
# Processing Record 344 for
# Processing Record 345 for
# Processing Record 346 for
# Processing Record 347 for
# Processing Record 348 for
# City not found. Skipping City...
# Processing Record 349 for
# Processing Record 350 for
# Processing Record 351 for
# Processing Record 352 for
# Processing Record 353 for
# Processing Record 354 for
# City not found. Skipping City...
# Processing Record 355 for
# Processing Record 356 for
# City not found. Skipping City...
# Processing Record 357 for
# Processing Record 358 for
# Processing Record 359 for
# Processing Record 360 for
# Processing Record 361 for
# Processing Record 362 for
# City not found. Skipping City...
# Processing Record 363 for
# Processing Record 364 for
# City not found. Skipping City...
# Processing Record 365 for
# Processing Record 366 for
# Processing Record 367 for
# Processing Record 368 for
# Processing Record 369 for
# City not found. Skipping City...
# Processing Record 370 for
# Processing Record 371 for
# Processing Record 372 for
# Processing Record 373 for
# Processing Record 374 for
# Processing Record 375 for
# Processing Record 376 for
# Processing Record 377 for
# Processing Record 378 for
# Processing Record 379 for
# City not found. Skipping City...
# City not found. Skipping City...
# Processing Record 380 for
# Processing Record 381 for
# Processing Record 382 for
# Processing Record 383 for
# Processing Record 384 for
# Processing Record 385 for
# Processing Record 386 for
# Processing Record 387 for
# Processing Record 388 for
# Processing Record 389 for
# Processing Record 390 for
# Processing Record 391 for
# Processing Record 392 for
# Processing Record 393 for
# Processing Record 394 for
# Processing Record 395 for
# Processing Record 396 for
# Processing Record 397 for
# Processing Record 398 for
# City not found. Skipping City...
# Processing Record 399 for
# Processing Record 400 for
# Processing Record 401 for
# Processing Record 402 for
# Processing Record 403 for
# Processing Record 404 for
# City not found. Skipping City...
# Processing Record 405 for
# Processing Record 406 for
# Processing Record 407 for
# Processing Record 408 for
# Processing Record 409 for
# Processing Record 410 for
# Processing Record 411 for
# Processing Record 412 for
# Processing Record 413 for
# Processing Record 414 for
# Processing Record 415 for
# Processing Record 416 for
# Processing Record 417 for
# City not found. Skipping City...
# Processing Record 418 for
# Processing Record 419 for
# Processing Record 420 for
# Processing Record 421 for
# Processing Record 422 for
# City not found. Skipping City...
# Processing Record 423 for
# Processing Record 424 for
# Processing Record 425 for
# Processing Record 426 for
# Processing Record 427 for
# Processing Record 428 for
# City not found. Skipping City...
# Processing Record 429 for
# Processing Record 430 for
# Processing Record 431 for
# Processing Record 432 for
# Processing Record 433 for
# Processing Record 434 for
# Processing Record 435 for
# Processing Record 436 for
# Processing Record 437 for
# City not found. Skipping City...
# Processing Record 438 for
# Processing Record 439 for
# Processing Record 440 for
# Processing Record 441 for
# City not found. Skipping City...
# Processing Record 442 for
# Processing Record 443 for
# Processing Record 444 for
# Processing Record 445 for
# Processing Record 446 for
# Processing Record 447 for
# Processing Record 448 for
# Processing Record 449 for
# Processing Record 450 for
# City not found. Skipping City...
# Processing Record 451 for
# Processing Record 452 for
# Processing Record 453 for
# City not found. Skipping City...
# Processing Record 454 for
# Processing Record 455 for
# Processing Record 456 for
# Processing Record 457 for
# Processing Record 458 for
# Processing Record 459 for
# Processing Record 460 for
# Processing Record 461 for
# Processing Record 462 for
# Processing Record 463 for
# Processing Record 464 for
# Processing Record 465 for
# Processing Record 466 for
# Processing Record 467 for
# Processing Record 468 for
# Processing Record 469 for
# Processing Record 470 for
# Processing Record 471 for
# City not found. Skipping City...
# Processing Record 472 for
# Processing Record 473 for
# Processing Record 474 for
# Processing Record 475 for
# Processing Record 476 for
# Processing Record 477 for
# Processing Record 478 for
# Processing Record 479 for
# Processing Record 480 for
# Processing Record 481 for
# Processing Record 482 for
# Processing Record 483 for
# Processing Record 484 for
# Processing Record 485 for
# Processing Record 486 for
# Processing Record 487 for
# Processing Record 488 for
# Processing Record 489 for
# Processing Record 490 for
# Processing Record 491 for
# Processing Record 492 for
# Processing Record 493 for
# Processing Record 494 for
# Processing Record 495 for
# Processing Record 496 for
# Processing Record 497 for
# Processing Record 498 for
# Processing Record 499 for
# Processing Record 500 for
# Processing Record 501 for
# Processing Record 502 for
# Processing Record 503 for
# Processing Record 504 for
# City not found. Skipping City...
# Processing Record 505 for
# Processing Record 506 for
# Processing Record 507 for
# Processing Record 508 for
# Processing Record 509 for
# Processing Record 510 for
# Processing Record 511 for
# Processing Record 512 for
# Processing Record 513 for
# City not found. Skipping City...
# Processing Record 514 for
# Processing Record 515 for
# Processing Record 516 for
# Processing Record 517 for
# Processing Record 518 for
# Processing Record 519 for
# Processing Record 520 for
# Processing Record 521 for
# City not found. Skipping City...
# Processing Record 522 for
# Processing Record 523 for
# Processing Record 524 for
# Processing Record 525 for
# Processing Record 526 for
# Processing Record 527 for
# Processing Record 528 for
# Processing Record 529 for
# Processing Record 530 for
# City not found. Skipping City...
# Processing Record 531 for
# Processing Record 532 for
# Processing Record 533 for
# City not found. Skipping City...
# Processing Record 534 for

# %%
for names in out_cities:
    print(names["name"])
# Out:
# Alta
# Mataura
# Tehri
# Batemans Bay
# Buchanan
# Albany
# Necochea
# Ushuaia
# Cabo San Lucas
# Mount Gambier
# Port Hardy
# Tuktoyaktuk
# Bethel
# Katangli
# Vaini
# Arraial do Cabo
# San Patricio
# Muskegon
# Rikitea
# Port Lincoln
# Lagodekhi
# Parbatipur
# Berdigestyakh
# Punta Arenas
# Caraballeda
# Victoria
# Hobart
# Lovozero
# Broome
# Isangel
# Castro
# Bredasdorp
# Sao Filipe
# Leningradskiy
# Cockburn Town
# Katobu
# Alice Springs
# Cape Town
# Najran
# Road Town
# Katsuura
# Cuenca
# Kuznechnoye
# Kaitangata
# Bilibino
# Yellowknife
# Husavik
# Yinchuan
# Kyshtovka
# Saskylakh
# Carnarvon
# Kamaishi
# Maldonado
# Barrow
# Qaanaaq
# Jamestown
# Seara
# Benjamin Hill
# Busselton
# Thompson
# Kapaa
# Quelimane
# Pevek
# Kiama
# Severo-Kurilsk
# Avarua
# Bambous Virieux
# Ribeira Grande
# Porto Novo
# Melilla
# East London
# Fortuna
# Chuy
# Shihezi
# Yerbogachen
# Tilichiki
# Mapiri
# Saint-Philippe
# Bonao
# North Fort Myers
# Constitucion
# Huesca
# Peterhead
# Huilong
# Puerto Ayora
# Bluff
# Cherskiy
# Homer
# Vestmannaeyjar
# Palomares
# Coihaique
# Iskitim
# Saint-Francois
# Barkot
# Georgetown
# Provideniya
# Ballina
# Tashtagol
# Neiafu
# Tasiilaq
# Acapulco
# Palana
# Seminole
# Saint-Augustin
# Norman Wells
# Quatre Cocos
# Dikson
# Hilo
# Kieta
# Cosolapa
# Shimanovsk
# Krasnoarmeysk
# Lloydminster

# %%
df = pd.DataFrame(out_cities)

# %%
clean_out_cities = [{
    "City Name": d["name"],
    "Country": d["sys"]["country"],
    "Cloudiness (%)": d["clouds"]["all"],
    "Humidity (%)": d["main"]["humidity"],
    "Temperature (F)": d["main"]["temp"],
    "Wind Speed (mph)": d["wind"]["speed"],
    "Latitude": d["coord"]["lat"],
    "Longitude": d["coord"]["lon"]
} for d in out_cities]

# %%
weather_df = pd.DataFrame(clean_out_cities)

# %%
weather_df
# Out:
#          City Name Country  Cloudiness (%)  Humidity (%)  Temperature (F)  \
# 0             Alta      NO             100            67            16.99
# 1          Mataura      NZ             100            84            48.99
# 2            Tehri      IN             100            41            42.19
# 3     Batemans Bay      AU             100            69            68.00
# 4         Buchanan      LR              20            88            68.00
# ..             ...     ...             ...           ...              ...
# 529          Kieta      PG               0            67            85.80
# 530       Cosolapa      MX             100            87            64.58
# 531     Shimanovsk      RU             100            92            -5.22
# 532  Krasnoarmeysk      RU              90            86            31.44
# 533   Lloydminster      CA              20            67            19.40
#
#      Wind Speed (mph)  Latitude  Longitude
# 0               12.75     69.97      23.27
# 1               25.99    -46.19     168.86
# 2                2.91     30.38      78.48
# 3               11.01    -35.71     150.18
# 4                5.82      5.88     -10.05
# ..                ...       ...        ...
# 529              6.11     -6.22     155.63
# 530              2.19     18.60     -96.68
# 531              2.71     52.00     127.67
# 532              6.71     56.12      38.15
# 533             11.41     53.28    -110.01
#
# [534 rows x 8 columns]

# %%
#Temperature (F) vs. Latitude Scatter Plot
plt.figure(figsize = (15,10))

plt.scatter(weather_df["Latitude"], weather_df["Temperature (F)"], color= "#0000ff", label= "City")

plt.grid()
plt.legend(title= "Legend", loc= "lower left")
plt.title("Temperature (F) vs. Latitude (01/05/20)")
plt.xlabel("Latitude")
plt.ylabel("Temperature (F)")
           
plt.savefig("Temperature vs Latitude.png")
plt.show()

plt.close()

# %%
# Humidity (%) vs. Latitude Scatter Plot

plt.figure(figsize = (15,10))

plt.scatter(weather_df["Latitude"], weather_df["Humidity (%)"], color= "#808080", label= "City")

plt.grid()
plt.legend(title= "Legend", loc= "lower left")
plt.title("Humidity (%) vs. Latitude (01/05/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
           
plt.savefig("Humidity vs Latitude.png")
plt.show()

plt.close()

# %%
# Cloudiness (%) vs. Latitude Scatter Plot

plt.figure(figsize = (15,10))

plt.scatter(weather_df["Latitude"], weather_df["Cloudiness (%)"], color= "#ff0000", label= "City")

plt.grid()
plt.legend(title= "Legend", loc= "lower left")
plt.title("Cloudiness (%) vs. Latitude (01/05/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
           
plt.savefig("Cloudiness vs Latitude.png")
plt.show()

plt.close()

# %%
# Wind Speed (mph) vs. Latitude Scatter Plot

plt.figure(figsize = (15,10))

plt.scatter(weather_df["Latitude"], weather_df["Wind Speed (mph)"], color= "#00ff00", label= "City")

plt.grid()
plt.legend(title= "Legend", loc= "lower left")
plt.title("Wind Speed (mph) vs. Latitude (01/05/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
           
plt.savefig("Wind Speed vs Latitude.png")
plt.show()

plt.close()
